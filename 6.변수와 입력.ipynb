# %%
#변수 만들기 (63P)
"영문 문자와 숫자를 사용할 수 있다."
"대소문자를 구분한다"
"문자부터 시작해야 하며 숫자부터 시작하면 안된다"
"_로 시작할수있다."
"특수문자는 사용할수없다."
"파이썬의 키워드는 사용할수없다."
"단어와 단어 사이는 띄울수없다."
#=기호는 같다가 아니라 값을 할당한다는 뜻. ==이 같다는 기호.

x=10
y='hello world'
X=15.15
print(x);print(type(x))
print(y);print(type(y))
print(X);print(type(X))
# Out:
# 10
# <class 'int'>
# hello world
# <class 'str'>
# 15.15
# <class 'float'>

# %%
#변수 여러 개를 한 번에 만들기
a,s,d,f=1,2,3,4
print(a)
print(s)
print(d,f)
# Out:
# 1
# 2
# 3 4

# %%
#변수의 값 바꾸기
a,b=1,2
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 1 2
# 2 1

# %%
a=1
b=2
a=a+10
b+=10
print(a,b)
# Out:
# 11 12

# %%
#입력값을 변수 두 개에 저장하기
a,b=input("문자열 두 개를 입력하시오").split()
print(a,b)
# Out:
# a b

# %%
a, b = map(int, input("숫자 두 개를 입력하시오: ").split())
print(a, b)
# Out:
# 1 2

# %%
a, b = map(int, input("숫자 두 개를 입력하시오: ").split(','))
print(a, b)
# Out:
# 515 47523

# %%
a,b = map(float, input('실수를 입력해라').split())

# %%
print(a,b)
# Out:
# 1.52 1.85

# %%
c=None
print(c)
# Out:
# None

# %%
a,b,c,d=map(int,input().split())
print((a+b+c+d)//4)
# Out:
# 50
