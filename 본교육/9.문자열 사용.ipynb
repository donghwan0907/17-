# %%
#hello='Hello World!'
print(hello)
# Out:
# Hello World!

# %%
#큰따옴표 3개나 작은따옴표 3개로 줄바꾸기
hi="""hi
my
Name
is
donghwan"""

print(hi)
# Out:
# hi
# my
# Name
# is
# donghwan

# %%
print('Hello\nworld')
print("python isn\'t difficult")
# Out:
# Hello
# world
# python isn't difficult

# %%
#문제 9.4
print("""'Python' is a "programming language"
that lets you work quickly
and
integrate ststems more effectively""")
# Out:
# 'Python' is a "programming language"
# that lets you work quickly
# and
# integrate ststems more effectively
