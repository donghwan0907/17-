# %%
#클래스 속성 사용하기
#class 클래스이름:
#   속성 = 값

class Person:
    bag=[]

    def put_bag(self, stuff):
        self.bag.append(stuff)

james=Person()
james.put_bag("책")

maria=Person()
maria.put_bag("열쇠")

print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %%
print(Person.bag)
# Out:
# ['책', '열쇠']

# %%
#인스턴트 속성 사용하기
class Person:
    def __init__(self):
        self.bag=[]

    def put_bag(self, stuff):
        self.bag.append(stuff)

james=Person()
james.put_bag("책")

maria=Person()
maria.put_bag("열쇠")

print(james.bag)
print(maria.bag)
# Out:
# ['책']
# ['열쇠']

# %%
#비공개 클래스 속성 사용하기
# class 클래스이름:
#     __속성=값

class Knight:
    __item_limit=10

    def print_item_limit(self):
        print(Knight.__item_limit)

x=Knight()
x.print_item_limit()

# print(Knight.__item_limit) 클래스 밖에는 접근불가
# Out:
# 10

# %%
#정적 메서드 사용
# class zmffotmdlfma:
#     @staticmethod
#     def 메서드(매개변수1, 매개변수2):
#         코드

class Calc:
    @staticmethod
    def add(a,b):
        print(a+b)

    @staticmethod
    def mul(a,b):
        print(a*b)

Calc.add(10,20)
Calc.mul(10,20)
# Out:
# 30
# 200

# %%
#클래스 메서드

# class 클래스이름:
#     @classmethod
#     def 메서드(cls, 매개변수1, 매개변수2):
#         코드

class Person:
    count=0

    def __init__(self):
        Person.count+=1

    @classmethod
    def print_count(cls):
        print('{0}명 생성되었습니다.'.format(cls.count))

james = Person()
maria = Person()

Person.print_count()
# Out:
# 2명 생성되었습니다.

# %%
#심사문제
class Time:
    def __init__(self, hour, minute, second):
        self.hour=hour
        self.minute=minute
        self.second=second

    def time_string(hour, minute, second):
        



    time_string=input()

    if Time.is_time_vaild(time_string):
        t=Time.from_string(time_string)
        print(t.hour, t.minute, t.second)
    else:
        print('잘못된 시간 형식입니다.')
