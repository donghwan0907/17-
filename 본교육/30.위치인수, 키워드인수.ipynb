# %%
#위치 인수를 사용하는 함수
def p_num(a,b,c):
    print(a)
    print(b)
    print(c)

# %%
p_num(10,20,30)
# Out:
# 10
# 20
# 30

# %%
#언패킹 사용하기
x=[40,50,60]
print(x)
print("ㅡㅡ")
print(*x)
print("ㅡㅡ")
p_num(*x)
# Out:
# [40, 50, 60]
# ㅡㅡ
# 40 50 60
# ㅡㅡ
# 40
# 50
# 60

# %%
#가변인수함수
def p_num(*args):
    for arg in args:
        print(arg)

# %%
p_num(10)
p_num(10,20,30,40)
# Out:
# 10
# 10
# 20
# 30
# 40

# %%
x=[10]
p_num(*x)
p_num(x)
# Out:
# 10
# [10]

# %%
y=[10,20,30,40]
p_num(*y)
p_num(y)
# Out:
# 10
# 20
# 30
# 40
# [10, 20, 30, 40]

# %%
#키워드 인수 사용하기
def perinfo(name,age,address):
    print('이름:',name)
    print('나이:',age)
    print('주소:',address)

perinfo("홍길동","30","서울시 용산구")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
#키워드인수로 사용하면 순서를 이름 나이 주소가 아닌 순서로 써도 출력됨.
perinfo(name='홍길동',address="서울시 용산구",age=30)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
#키워드인수와 딕셔너리 언패킹
def perinfo(name,age,address):
    print('이름:',name)
    print('나이:',age)
    print('주소:',address)
    
x= {'name':'홍길동','age':30,'address':'서울시 용산구'}
perinfo(**x)
#별표를 두 번 넣어야 함(한번 넣으면 키가 출력, 두번 넣어야 값이 출력.)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
#키워드 인수를 사용하는 가변인수함수 만들기 (**)
def perinfo(**kwargs):
    for kw, arg in kwargs.items():
        print(kw,':', arg,sep='')

perinfo(name='홍길동',age=30,address='서울시 용산구')
# Out:
# name:홍길동
# age:30
# address:서울시 용산구

# %%
y={'name':'홍길동','age':30,'address':'서울시 용산구'}
perinfo(**y)
# Out:
# name:홍길동
# age:30
# address:서울시 용산구

# %%
#매개변수에 초깃값 지정하기
def perinfo(name,age,address='비공개'):
    print('이름:',name)
    print('나이:',age)
    print('주소:',address)

# %%
#2개만 썼을 때 에러가 발생했는데, 초깃값을 설정하면 초깃값이 출력됨.
perinfo('홍길동',30)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 비공개

# %%
def perinfo(name,age='비공개',address='비공개'):
    print('이름:',name)
    print('나이:',age)
    print('주소:',address)

# %%
perinfo('홍길동')
# Out:
# 이름: 홍길동
# 나이: 비공개
# 주소: 비공개

# %%
def perinfo(name='비공개',age='비공개',address='비공개'):
    print('이름:',name)
    print('나이:',age)
    print('주소:',address)
perinfo()

#초깃값이 중간이나 앞에만 있다면 에러가 발생.
#입력값이 어디에 들어갈지 모르기 때문.
#따라서, 초깃값을 설정한 것은 뒷쪽으로 몰아주어야함.
# Out:
# 이름: 비공개
# 나이: 비공개
# 주소: 비공개

# %%
#심사문제
국,영,수,과=map(int,input().split())
def min_score(*args):
    return min(args)
def max_score(*args):
    return max(args)
def get_min_max_score(*args):

min_score, max score = get_min max score(korean, english, mathematics, science) average_score = get_average(korean=korean, english=english,

mathematics=mathematics, science=science)

.format(min_score, max_score, average_score))

print('낮은 점수: {:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2: 2f)'

min_score, max_score = get_min_max_score(english, science) average_score = get_average(english=english, science=science) print('낮은 점수: {0:2f), 높은 점수: {1:.2f}, 평균 점수: {2:.2f} .format(min_score, max_score, average_score))
