# %%
#if 안에는 =를 쓸 수 없음.
x=5
if x==5:#x=5 하면 에러
    print("d")
# Out:
# d

# %%
x=int(input())
if x ==10:
    pass #아무것도 하지 않고 지나감.
else:
    print("not 10")
# Out:
# not 10

# %%
x=int(input())
if x ==10:
    print("10이다.")
if x==15:
    print("15다.")
# Out:
# 15다.

# %%
#심사문제
가격=int(input())
쿠폰=int(input())
print(가격-쿠폰)
# Out:
# 67000
