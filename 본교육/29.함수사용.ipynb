# %%
#함수만들기
def h():
    print("hello, world!")
h()
# Out:
# hello, world!

# %%
def add(a,b):
    print(a+b)

add(1,2)
# Out:
# 3

# %%
def add(a,b):
    """이 함수는  a와b를 더한 뒤 결과를 반환하는 함수입니다."""
    return a+b
x=add(10,20)
print(x)
print(add.__doc__)
# Out:
# 30
# None
