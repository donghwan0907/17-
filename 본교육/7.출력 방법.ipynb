# %%
#값을 여러개 출력하기
print(1,2,3)
print("hello", "python")
# Out:
# 1 2 3
# hello python

# %%
#sep로 값 사이에 문자 넣기
print(1,2,3,sep=",") #값 사이에 ,를 넣어라
print(1,2,3,sep="") #값 사이에 공백을 넣어라
print(1920,1000,sep="X")
# Out:
# 1,2,3
# 123
# 1920X1000
