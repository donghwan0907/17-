# %%
#while은 조건문이 True일때까지 반복한다.
i=0
while i<10: #->i가 10일때부터는 조건식이 False가 되므로 정지함.
    print('hello',i)
    i+=1
# Out:
# hello 0
# hello 1
# hello 2
# hello 3
# hello 4
# hello 5
# hello 6
# hello 7
# hello 8
# hello 9

# %%
tryy = 1
password = "tmdfl"
pw = input()
while pw != password:
    print("비밀번호가 틀렸습니다.", "(", tryy, "번째 시도)")
    tryy += 1
    if tryy == 6:
        print("계정이 잠겼습니다.")
        break

    pw = input("비밀번호를 다시 입력하세요: ")
if pw==passward:
    print("로그인 되었습니다.")
# Out:
# 비밀번호가 틀렸습니다. ( 1 번째 시도)
# 비밀번호가 틀렸습니다. ( 2 번째 시도)
# 비밀번호가 틀렸습니다. ( 3 번째 시도)
# 비밀번호가 틀렸습니다. ( 4 번째 시도)
# 비밀번호가 틀렸습니다. ( 5 번째 시도)
# 계정이 잠겼습니다.

# %%
#반복 횟수가 정해지지 않음
import random
random.random()
# Out:
# 5

# %%
random.randint(1,6)
# Out:
# 6

# %%
import random
i=0
cnt=1
while i!=3:
    i=random.randint(1,20)
    print(i,cnt,"번째시도")
    cnt+=1
# Out:
# 6 1 번째시도
# 4 2 번째시도
# 7 3 번째시도
# 13 4 번째시도
# 19 5 번째시도
# 17 6 번째시도
# 10 7 번째시도
# 20 8 번째시도
# 4 9 번째시도
# 20 10 번째시도
# 13 11 번째시도
# 6 12 번째시도
# 3 13 번째시도

# %%
import random
i=random.randint(1,100)
print(i)
# Out:
# 25

# %%
#심사문제
금액=int(input())
while 금액>=1350:
    금액-=1350
    print(금액)
# Out:
# 12150
# 10800
# 9450
# 8100
# 6750
# 5400
# 4050
# 2700
# 1350
# 0
