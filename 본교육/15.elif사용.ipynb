# %%
#심사문제
나이=int(input())
while 나이 < 7:
    print("다시 입력하세요.")
    나이 = int(input("나이 입력: "))
if 12>=나이>=7:
    가격=650
elif 18>=나이>=13:
    가격=1050
else:
    가격=1250
잔액=9000
print(잔액-가격)
# Out:
# 다시 입력하세요.
# 7950
