# %%
#if 조건문에 숫자 지정
if 0:
    print("참")
else:
    print("거짓")

if 1:
    print("참")
else:
    print("거짓")

if '':
    print("참")
else:
    print("거짓")

if []:
    print("참")
else:
    print("거짓")

if None:
    print("참")
else:
    print("거짓")
# Out:
# 거짓
# 참
# 거짓
# 거짓
# 거짓

# %%
x=0
x=False
y=1
if x or y:
    print("tr")
else:
    print("f")
# Out:
# tr

# %%
#심사문제
a, b, c, d = map(int, input().split())
if a < 0 or a > 100 or b < 0 or b > 100 or c < 0 or c > 100 or d < 0 or d > 100:
    print("잘못된 점수")
elif (a+b+c+d)/4 >=80:
    print("합격")
else:
    print("불합격")
# Out:
# 잘못된 점수
